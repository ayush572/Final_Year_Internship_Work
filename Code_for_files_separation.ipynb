# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush572/Final_Year_Internship_Work/blob/main/Code_for_files_separation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
csv_file_path = '/content/drive/MyDrive/Genre_mapping - All Genres.csv'
# Load the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)

# Display the DataFrame
print("DataFrame:")
df.head()
# Out:
# DataFrame:
#                            Genres Y/N    Count  Count in Fiction  \
# 0  ['Animals & Wild life & Pets']   y   6864.0               NaN
# 1          ['Arts & Photography']   y  10538.0               NaN
# 2        ['Biographies & Memoir']   y  15334.0               NaN
# 3            ['Business & Money']   y   3103.0               NaN
# 4              ['Childrens Book']   y  21432.0               NaN
#
#    Count in Non-Fiction In case the fic/nonfic is missing
# 0                   NaN                               NaN
# 1                   NaN                               NaN
# 2                   NaN                           fiction
# 3                   NaN                               NaN
# 4                   NaN                           fiction

# %%
import pandas as pd
csv_file_path = '/content/drive/MyDrive/Genre_mapping - New Mapping Updated.csv'
# Load the CSV file into a pandas DataFrame
df1 = pd.read_csv(csv_file_path)

# Display the DataFrame
print("DataFrame:")
df1.head()
# Out:
# DataFrame:
#   Category                       1st Genre 2nd Genre 3rd Genre
# 0  Animals  ['Animals & Wild life & Pets']       NaN       NaN
# 1   Horses  ['Animals & Wild life & Pets']       NaN       NaN
# 2     Dogs  ['Animals & Wild life & Pets']       NaN       NaN
# 3     Cats  ['Animals & Wild life & Pets']       NaN       NaN
# 4   Wolves  ['Animals & Wild life & Pets']       NaN       NaN

# %%
df1.keys()
# Out:
# Index(['Category', '1st Genre', '2nd Genre', '3rd Genre'], dtype='object')

# %%
import pandas as pd
csv_file_path = '/content/drive/MyDrive/Book Dataset - merge_data_analysis.csv'
# Load the CSV file into a pandas DataFrame
df2 = pd.read_csv(csv_file_path)

# Display the DataFrame
print("DataFrame:")
df2.head()
# Out:
# DataFrame:
# <ipython-input-5-0f2f47f08d74>:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(csv_file_path)
#             ISBN  fiction_nonfiction  first_3_categories  coverpage  \
# 0  9780439095020                   1                   1          1
# 1  9780446310789                   1                   1          1
# 2  9780553062045                   1                   1          1
# 3  9780316769488                   1                   1          1
# 4  9788445071403                   1                   1          1
#
#    description  ocr  total
# 0            1    1      5
# 1            1    1      5
# 2            1    1      5
# 3            1    1      5
# 4            1    1      5

# %%
import pandas as pd
csv_file_path = '/content/drive/MyDrive/Final_consolidate_file.csv'
# Load the CSV file into a pandas DataFrame
df3 = pd.read_csv(csv_file_path)

# Display the DataFrame
print("DataFrame:")
df3.head()
# Out:
# DataFrame:
#          ISBN-13                                             Genres  \
# 0  9780195153446  Mythology, Nonfiction, History, Classics, Refe...
# 1  9780002005012  Fiction, Canada, Historical Fiction, Literary ...
# 2  9780060973124  History, World War IINonfiction, Military Hist...
# 3  9780374157067  History, Nonfiction, Science, Medical, Medicin...
# 4  9780393045215  History, Archaeology, Nonfiction, China, Anthr...
#
#       Coverpage   Description
# 0    846427.jpg    846427.txt
# 1    969335.jpg    969335.txt
# 2  no-cover.png  no-cover.txt
# 3    893390.jpg    893390.txt
# 4   1357556.jpg   1357556.txt

# %%
len(df3)
# Out:
# 261615

# %%
len(df2)
# Out:
# 258333

# %%
len(df1)
# Out:
# 1838

# %%
all_genres = df["Genres"]
all_genres = all_genres.tolist()
all_genres
# Out:
# ["['Animals & Wild life & Pets']",
#  "['Arts & Photography']",
#  "['Biographies & Memoir']",
#  "['Business & Money']",
#  "['Childrens Book']",
#  "['Comics & Graphic']",
#  "['Computers & Technology']",
#  "['Cookbooks, Food & Wine']",
#  "['Crafts, Hobbies & Home']",
#  "['Engineering & Transportation']",
#  "['Family & Parenting & Relationships']",
#  "['Fashion & Lifestyle']",
#  "['Health, Fitness & Dieting']",
#  "['History']",
#  "['Humanities']",
#  "['Humor & Entertainment']",
#  "['Law']",
#  "['Literature']",
#  "['Medical']",
#  "['Mystery, Thriller, Suspense & Horror']",
#  "['Mythology & Religion & Spirituality']",
#  "['Romance']",
#  "['Science & Math & Mathematics']",
#  "['Science Fiction & Fantasy']",
#  "['Sports & Outdoors']",
#  "['Teen & Young Adult']",
#  "['Travel']",
#  "['Environment & Plant']",
#  "['Calendars']",
#  "['Christian Books & Bibles']",
#  "['Reference & Language']",
#  "['Religion & Spirituality']",
#  "['Self-Help & Motivation']",
# ...

# %%
# Given list of genres
# genres = ["['Arts & Photography']", "['Biographies & Memoir']", "['Business & Money']", "['Childrens Book']", "['Comics & Graphic']", "['Computers & Technology']", "['Cookbooks, Food & Wine']", "['Crafts, Hobbies & Home']", "['Engineering & Transportation']", "['Family & Parenting & Relationships']", "['Fashion & Lifestyle']", "['Health, Fitness & Dieting']", "['History']", "['Humanities']", "['Humor & Entertainment']", "['Law']", "['Literature']", "['Medical']", "['Mystery, Thriller, Suspense & Horror']", "['Mythology & Religion & Spirituality']", "['Romance']", "['Science & Math & Mathematics']", "['Science Fiction & Fantasy']", "['Sports & Outdoors']", "['Teen & Young Adult']", "['Travel']", "['Environment & Plant']", "['Calendars']", "['Christian Books & Bibles']", "['Reference & Language']", "['Religion & Spirituality']", "['Self-Help']", "['Test Preparation']"]

# Clean up the genre names
cleaned_genres = [genre.strip("[]").replace("'", "").replace("&", "&").replace(", ", " & ") for genre in all_genres]

print(cleaned_genres)
# Out:
# ['Animals & Wild life & Pets', 'Arts & Photography', 'Biographies & Memoir', 'Business & Money', 'Childrens Book', 'Comics & Graphic', 'Computers & Technology', 'Cookbooks & Food & Wine', 'Crafts & Hobbies & Home', 'Engineering & Transportation', 'Family & Parenting & Relationships', 'Fashion & Lifestyle', 'Health & Fitness & Dieting', 'History', 'Humanities', 'Humor & Entertainment', 'Law', 'Literature', 'Medical', 'Mystery & Thriller & Suspense & Horror', 'Mythology & Religion & Spirituality', 'Romance', 'Science & Math & Mathematics', 'Science Fiction & Fantasy', 'Sports & Outdoors', 'Teen & Young Adult', 'Travel', 'Environment & Plant', 'Calendars', 'Christian Books & Bibles', 'Reference & Language', 'Religion & Spirituality', 'Self-Help & Motivation', 'Test Preparation', 'Press & Media', 'Meta Text', 'Astrology', 'Total']

# %%
cleaned_genres.remove('Total')

# %%
cleaned_genres
# Out:
# ['Animals & Wild life & Pets',
#  'Arts & Photography',
#  'Biographies & Memoir',
#  'Business & Money',
#  'Childrens Book',
#  'Comics & Graphic',
#  'Computers & Technology',
#  'Cookbooks & Food & Wine',
#  'Crafts & Hobbies & Home',
#  'Engineering & Transportation',
#  'Family & Parenting & Relationships',
#  'Fashion & Lifestyle',
#  'Health & Fitness & Dieting',
#  'History',
#  'Humanities',
#  'Humor & Entertainment',
#  'Law',
#  'Literature',
#  'Medical',
#  'Mystery & Thriller & Suspense & Horror',
#  'Mythology & Religion & Spirituality',
#  'Romance',
#  'Science & Math & Mathematics',
#  'Science Fiction & Fantasy',
#  'Sports & Outdoors',
#  'Teen & Young Adult',
#  'Travel',
#  'Environment & Plant',
#  'Calendars',
#  'Christian Books & Bibles',
#  'Reference & Language',
#  'Religion & Spirituality',
#  'Self-Help & Motivation',
#  'Test Preparation',
#  'Press & Media',
#  'Meta Text',
#  'Astrology']

# %%
all_books_number = df3['ISBN-13']

# %%
all_genres = df3['Genres']

# %%
listed_books_no = df2['ISBN']

# %%
genres_list = all_genres.tolist()
genres_list[6]
# Out:
# 'History, Nonfiction, Alternate History, Military History, Military Fiction, War, Essays '

# %%
import numpy as np
new_mod_list = []

# for string to list conversion
for idx, genres in enumerate(genres_list):
    if pd.notna(genres):  # Assuming you're using pandas and 'nan' is NaN
        new_mod_list.append(genres.split(', '))
    else:
        new_mod_list.append([np.nan])

# Display the resulting list
# print(new_mod_list)

# %%
new_mod_list
# Out:
# [['Mythology',
#   'Nonfiction',
#   'History',
#   'Classics',
#   'Reference',
#   'Textbooks',
#   'Religion '],
#  ['Fiction',
#   'Canada',
#   'Historical Fiction',
#   'Literary Fiction',
#   'Canadian Literature',
#   'Novels',
#   'Historical '],
#  ['History',
#   'World War IINonfiction',
#   'Military History',
#   'War',
#   'Military Fiction',
#   'World History '],
#  ['History',
#   'Nonfiction',
#   'Science',
#   'Medical',
#   'Medicine',
#   'Health',
#   'Disease '],
#  ['History',
#   'Archaeology',
#   'Nonfiction',
#   'China',
#   'Anthropology',
#   'Asia',
#   'Ancient History '],
#  ['Fiction',
#   'Historical Fiction',
#   'China',
#   'Asia',
#   'Contemporary',
#   'Asian Literature',
#   'Historical '],
#  ['History',
#   'Nonfiction',
#   'Alternate History',
#   'Military History',
#   'Military Fiction',
#   'War',
#   'Essays '],
#  ['Fiction',
#   'Mystery',
#   'Legal Thriller',
#   'Thriller',
#   'Crime',
#   'Mystery Thriller',
# ...

# %%
cat1_list = []

for list_data in new_mod_list:
    new_list_data = []
    temp_list = []
    nan_appended = False  # Flag to track whether np.nan has been appended
    flag = 0
    for string in list_data:
        if pd.notna(string):
            if 'Fiction' in string and 'Fiction' not in temp_list:
                temp_list.append('Fiction')
                if(len(string)>7):
                  new_list_data.append(string)
                flag=1
            elif 'Nonfiction' in string and 'Nonfiction' not in temp_list:
                temp_list.append('Nonfiction')
                if(len(string)>10):
                  new_list_data.append(string)
                flag=1
            else:
              if string!= 'Fiction' and string != 'Nonfiction':
                new_list_data.append(string)
                # print('came here and new list data is:', new_list_data)
        else:
            new_list_data.append(string)
            if not nan_appended:  # Append np.nan only once
                cat1_list.append(np.nan)
                nan_appended = True
    if not nan_appended:
      cat1_list.append(temp_list)

    # Update list_data with the new list
    list_data[:] = new_list_data

# %%
cat1_list
# Out:
# [['Nonfiction'],
#  ['Fiction'],
#  ['Nonfiction', 'Fiction'],
#  ['Nonfiction'],
#  ['Nonfiction'],
#  ['Fiction'],
#  ['Nonfiction', 'Fiction'],
#  ['Fiction'],
#  ['Nonfiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Nonfiction'],
#  nan,
#  ['Nonfiction'],
#  nan,
#  ['Nonfiction'],
#  nan,
#  ['Fiction'],
#  ['Fiction'],
#  ['Nonfiction'],
#  [],
#  nan,
#  ['Fiction'],
#  ['Nonfiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Nonfiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  nan,
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  nan,
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  nan,
#  ['Nonfiction'],
#  ['Fiction'],
#  nan,
#  ['Fiction'],
#  ['Nonfiction'],
#  nan,
#  nan,
#  ['Fiction'],
#  ['Fiction'],
#  ['Fiction'],
#  nan,
#  ['Nonfiction'],
# ...

# %%
new_mod_list
# Out:
# [['Mythology', 'History', 'Classics', 'Reference', 'Textbooks', 'Religion '],
#  ['Canada',
#   'Historical Fiction',
#   'Literary Fiction',
#   'Canadian Literature',
#   'Novels',
#   'Historical '],
#  ['History',
#   'World War IINonfiction',
#   'Military History',
#   'War',
#   'Military Fiction',
#   'World History '],
#  ['History', 'Science', 'Medical', 'Medicine', 'Health', 'Disease '],
#  ['History',
#   'Archaeology',
#   'China',
#   'Anthropology',
#   'Asia',
#   'Ancient History '],
#  ['Historical Fiction',
#   'China',
#   'Asia',
#   'Contemporary',
#   'Asian Literature',
#   'Historical '],
#  ['History',
#   'Alternate History',
#   'Military History',
#   'Military Fiction',
#   'War',
#   'Essays '],
#  ['Mystery',
#   'Legal Thriller',
#   'Thriller',
#   'Crime',
#   'Mystery Thriller',
#   'Suspense '],
#  ['History',
#   'Pirates',
#   'Historical',
#   'Adventure',
#   'Research',
#   'World History '],
#  ['Short Stories',
#   'Literature',
# ...

# %%
# unique genres data
new_list_data = []

for list_data in new_mod_list:
    temp_list = []
    nan_appended = False  # Flag to track whether np.nan has been appended
    flag = 0
    for string in list_data:
        if pd.notna(string):
            # if 'Fiction' in string and len(string)>7 and string not in new_list_data:
            #     new_list_data.append(string)
            # elif 'Nonfiction' in string and len(string)>10 and string not in new_list_data:
            #     new_list_data.append(string)
            # elif string not in new_list_data and string != 'Fiction' and string != 'Nonfiction':
            #     new_list_data.append(string)
            if string not in new_list_data:
              new_list_data.append(string)

# %%
len(new_list_data)
# Out:
# 2513

# %%
# Remove extra white spaces using list comprehension and strip()
all_genres_cleaned_list = [s.strip() for s in new_list_data]

# %%
unique_list = []
for item in all_genres_cleaned_list:
    if item not in unique_list:
        unique_list.append(item)
print(len(unique_list))
# Out:
# 2055

# %%
import pandas as pd
df = pd.DataFrame({
    'all unique categories': unique_list,
})
csv_file_path = '/content/drive/MyDrive/all_unique_cat_updated_latest.csv'
df.to_csv(csv_file_path, index=False)

# %%
import pandas as pd
csv_file_path = '/content/drive/MyDrive/all_unique_cat_updated_latest.csv'
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#   all unique categories
# 0             Mythology
# 1               History
# 2              Classics
# 3             Reference
# 4             Textbooks

# %%
all_unique_cat = df['all unique categories']
all_unique_cat = all_unique_cat.tolist()
all_unique_cat
# Out:
# ['Mythology',
#  'History',
#  'Classics',
#  'Reference',
#  'Textbooks',
#  'Religion',
#  'Canada',
#  'Historical Fiction',
#  'Literary Fiction',
#  'Canadian Literature',
#  'Novels',
#  'Historical',
#  'World War IINonfiction',
#  'Military History',
#  'War',
#  'Military Fiction',
#  'World History',
#  'Science',
#  'Medical',
#  'Medicine',
#  'Health',
#  'Disease',
#  'Archaeology',
#  'China',
#  'Anthropology',
#  'Asia',
#  'Ancient History',
#  'Contemporary',
#  'Asian Literature',
#  'Alternate History',
#  'Essays',
#  'Mystery',
#  'Legal Thriller',
#  'Thriller',
#  'Crime',
#  'Mystery Thriller',
#  'Suspense',
#  'Pirates',
#  'Adventure',
#  'Research',
#  'Short Stories',
#  'Literature',
#  'American',
#  'Anthologies20th Century',
#  'School',
#  'Holocaust',
#  'Inspirational',
#  'Self Help',
#  'Christian',
#  'Memoir',
#  'Adult',
#  'Magical Realism',
#  'Humor',
#  'Comedy',
#  'Politics',
#  'Journalism',
#  'Cookbooks',
#  'Food',
# ...

# %%
for idx, elem in enumerate(unique_list):
  if 'Death' == elem:
    print(idx)
# Out:
# 378

# %%
new_mapping_cat = df1['Category']
new_mapping_cat = new_mapping_cat.tolist()
new_mapping_cat
# Out:
# ['Animals',
#  'Horses',
#  'Dogs',
#  'Cats',
#  'Wolves',
#  'Wildlife',
#  'Dogs20th Century',
#  'Birds',
#  'Animal Fiction',
#  'Horse Racing',
#  'Animals20th Century',
#  'Dogs1st Grade',
#  'Animals1st Grade',
#  'Animal Fiction20th Century',
#  'Animals1st Grade2nd Grade',
#  'Animals2nd Grade',
#  'Dogs2nd Grade',
#  'Animals2nd Grade1st Grade',
#  'Animals19th Century',
#  'Animal Fiction1st Grade',
#  'Magical Realism',
#  'Cultural',
#  'Magic',
#  'Pop Culture',
#  'Art',
#  'Music',
#  'Music20th Century',
#  'Judaica',
#  'LGBTCultural',
#  'LGBTMusic',
#  'Martial Arts',
#  'Photography',
#  'Art History',
#  'Magick',
#  'Art and Photography',
#  'Counter Culture',
#  'Cultural Studies',
#  'LGBTMagic',
#  'Art Design',
#  'Art17th Century',
#  'Musicals',
#  'Origami',
#  'Classical Music',
#  'Art19th Century',
#  'LGBTMagical Realism',
#  'Music Biography',
#  'Art Design20th Century',
#  'Pop Culture20th Century',
#  'Magical Realism20th Century',
# ...

# %%
len(new_mapping_cat)
# Out:
# 1838

# %%
for val in new_mapping_cat:
  if pd.isna(val):
    print(val)
# Out:
# nan

# %%
first_genre = df1['1st Genre']
first_genre = first_genre.tolist()
first_genre
# Out:
# ["['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Animals & Wild life & Pets']",
#  "['Arts & Photography']",
#  "['Arts & Photography']",
#  "['Arts & Photography']",
#  "['Arts & Photography']",
#  "['Arts & Photography']",
#  "['Arts & Photography']",
#  "['Arts & Photography']",
#  "['Arts & Photography']",
# ...

# %%
len(first_genre)
# Out:
# 1838

# %%
import pandas as pd

# Clean up the genre names
cleaned_first_genre = [genre.strip("[]").replace("'", "").replace("&", "&").replace(", ", " & ") if pd.notna(genre) else genre for genre in first_genre]

print(cleaned_first_genre)
# Out:
# ['Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Animals & Wild life & Pets', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', 'Arts & Photography', '
# ...

# %%
second_genre = df1['2nd Genre']
second_genre = second_genre.tolist()
second_genre
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  "['Mythology & Religion & Spirituality']",
#  "['Fashion & Lifestyle']",
#  "['Fashion & Lifestyle']",
#  nan,
#  nan,
#  "['History']",
#  nan,
#  nan,
#  nan,
#  nan,
#  "['Fashion & Lifestyle']",
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  "['Fashion & Lifestyle']",
#  "['Biographies & Memoir']",
#  nan,
#  nan,
#  nan,
#  "['History']",
#  nan,
#  nan,
#  nan,
#  nan,
#  "['History']",
#  "['Fashion & Lifestyle']",
#  "['Fashion & Lifestyle']",
#  nan,
#  "['History']",
#  nan,
#  "['History']",
#  "['History']",
#  nan,
#  nan,
#  "['Literature']",
#  nan,
#  "['Fashion & Lifestyle']",
#  "['History']",
#  "['History']",
#  nan,
#  nan,
#  "['History']",
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  "['Fashion & Lifestyle']",
#  "['History']",
# ...

# %%
import pandas as pd

# Clean up the genre names
cleaned_second_genre = [genre.strip("[]").replace("'", "").replace("&", "&").replace(", ", " & ") if pd.notna(genre) else genre for genre in second_genre]

print(cleaned_second_genre)
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Mythology & Religion & Spirituality', 'Fashion & Lifestyle', 'Fashion & Lifestyle', nan, nan, 'History', nan, nan, nan, nan, 'Fashion & Lifestyle', nan, nan, nan, nan, nan, nan, 'Fashion & Lifestyle', 'Biographies & Memoir', nan, nan, nan, 'History', nan, nan, nan, nan, 'History', 'Fashion & Lifestyle', 'Fashion & Lifestyle', nan, 'History', nan, 'History', 'History', nan, nan, 'Literature', nan, 'Fashion & Lifestyle', 'History', 'History', nan, nan, 'History', nan, nan, nan, nan, nan, 'Fashion & Lifestyle', 'History', 'Fashion & Lifestyle', 'History', nan, nan, nan, 'History', 'Fashion & Lifestyle', nan, 'Fashion & Lifestyle', nan, nan, nan, 'History', 'History', nan, nan, nan, nan, 'Fashion & Lifestyle', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'History', nan, nan, nan, nan, 'History', nan, nan, nan, nan, 'Fa
# ...

# %%
third_genre = df1['3rd Genre']
third_genre = third_genre.tolist()
third_genre
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  "['Fashion & Lifestyle']",
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
import pandas as pd

# Clean up the genre names
cleaned_third_genre = [genre.strip("[]").replace("'", "").replace("&", "&").replace(", ", " & ") if pd.notna(genre) else genre for genre in third_genre]

print(cleaned_third_genre)
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Fashion & Lifestyle', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %%
new_mapping_cat # categories defined by mam
all_unique_cat # unique categories filtered out
cleaned_genres # has all the 34 genres
cleaned_first_genre # 1st genre from new_mapping_cat
cleaned_second_genre # 2nd genre from new_mapping_cat
cleaned_third_genre # 3rd genre from new_mapping_cat
all_books_number # all books ISBN-13 numbers
new_mod_list # has the list of the categories for a particular book

# %%
len(cleaned_genres)
# Out:
# 37

# %%
df2.head()
# Out:
#             ISBN  fiction_nonfiction  first_3_categories  coverpage  \
# 0  9780439095020                   1                   1          1
# 1  9780446310789                   1                   1          1
# 2  9780553062045                   1                   1          1
# 3  9780316769488                   1                   1          1
# 4  9788445071403                   1                   1          1
#
#    description  ocr  total
# 0            1    1      5
# 1            1    1      5
# 2            1    1      5
# 3            1    1      5
# 4            1    1      5

# %%
df3.head()
# Out:
#          ISBN-13                                             Genres  \
# 0  9780195153446  Mythology, Nonfiction, History, Classics, Refe...
# 1  9780002005012  Fiction, Canada, Historical Fiction, Literary ...
# 2  9780060973124  History, World War IINonfiction, Military Hist...
# 3  9780374157067  History, Nonfiction, Science, Medical, Medicin...
# 4  9780393045215  History, Archaeology, Nonfiction, China, Anthr...
#
#       Coverpage   Description
# 0    846427.jpg    846427.txt
# 1    969335.jpg    969335.txt
# 2  no-cover.png  no-cover.txt
# 3    893390.jpg    893390.txt
# 4   1357556.jpg   1357556.txt

# %%
listed_books_no
len(new_mapping_cat)
# Out:
# 1838

# %%
len(first_genre)
# Out:
# 1838

# %%
df4 = pd.read_csv('/content/drive/MyDrive/output_updated_latest.csv')
df4.head()
# Out:
#          ISBN-13 Fiction/Non-fiction  \
# 0  9780195153446          Nonfiction
# 1  9780002005012             Fiction
# 2  9780060973124          Nonfiction
# 3  9780374157067          Nonfiction
# 4  9780393045215          Nonfiction
#
#                                           Categories  \
# 0  Mythology & Religion & Spirituality, History, ...
# 1                                History, Literature
# 2                                            History
# 3  History, Science & Math & Mathematics, Medical...
# 4                                History, Humanities
#
#                               First Three Categories  \
# 0                       Mythology, History, Classics
# 1       Canada, Historical Fiction, Literary Fiction
# 2  History, World War IINonfiction, Military History
# 3                          History, Science, Medical
# 4                        History, Archaeology, China
#
#                        Remaining Categories
# 0           Reference, Textbooks, Religion
# ...

# %%
fic_nonfic = df4['Fiction/Non-fiction']

# %%
cat2_list= []
length = len(cleaned_genres)
cleaned_genres_numbers = [0] * length
fic_cleaned_genres_numbers = [0] * length
nonfic_cleaned_genres_numbers = [0] * length

#new_mod_list is free from fiction and nonfiction values
for num in listed_books_no:
  for indx, book_no in enumerate(all_books_number):
    if num == book_no:
      temp_list = []
      for string in new_mod_list[indx]:
        if pd.notna(string):
          for idx, data in enumerate(new_mapping_cat):
            if pd.isna(data):
              continue
            else:
              if string == data:
                if pd.notna(cleaned_first_genre[idx]) and cleaned_first_genre[idx] not in temp_list:
                  temp_list.append(cleaned_first_genre[idx])
                  # this inner loop is for keeping the track of the count
                  for index, genre in enumerate(cleaned_genres):
                    if cleaned_first_genre[idx] == genre:
                      cleaned_genres_numbers[index] += 1
                      if pd.notna(fic_nonfic[indx]):
                        if fic_nonfic[indx] == 'Fiction':
                          fic_cleaned_genres_numbers[index] += 1
                        elif fic_nonfic[indx] == 'Nonfiction':
                          nonfic_cleaned_genres_numbers[index] += 1
                if pd.notna(cleaned_second_genre[idx]) and cleaned_second_genre[idx] not in temp_list:
                  temp_list.append(cleaned_second_genre[idx])
                  for index, genre in enumerate(cleaned_genres):
                    if cleaned_second_genre[idx] == genre:
                      cleaned_genres_numbers[index] += 1
                      if pd.notna(fic_nonfic[indx]):
                        if fic_nonfic[indx] == 'Fiction':
                          fic_cleaned_genres_numbers[index] += 1
                        elif fic_nonfic[indx] == 'Nonfiction':
                          nonfic_cleaned_genres_numbers[index] += 1
                if pd.notna(cleaned_third_genre[idx]) and cleaned_third_genre[idx] not in temp_list:
                  temp_list.append(cleaned_third_genre[idx])
                  for index, genre in enumerate(cleaned_genres):
                    if cleaned_third_genre[idx] == genre:
                      cleaned_genres_numbers[index] += 1
                      if pd.notna(fic_nonfic[indx]):
                        if fic_nonfic[indx] == 'Fiction':
                          fic_cleaned_genres_numbers[index] += 1
                        elif fic_nonfic[indx] == 'Nonfiction':
                          nonfic_cleaned_genres_numbers[index] += 1
        elif pd.isna(string):
          break
      if len(temp_list) == 0:
        temp_list.append(np.nan)
      cat2_list.append(temp_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-d0992a70fce9> in <cell line: 8>()
#       8 for num in listed_books_no:
#       9   for indx, book_no in enumerate(all_books_number):
# ---> 10     if num == book_no:
#      11       temp_list = []
#      12       for string in new_mod_list[indx]:
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df_cleaned_updated = pd.read_csv('/content/drive/MyDrive/output_updated_latest_cleaned.csv')
# Out:
# <ipython-input-85-a62a84605e1f>:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cleaned_updated = pd.read_csv('/content/drive/MyDrive/output_updated_latest_cleaned.csv')

# %%
df_cleaned_updated
# Out:
#         Unnamed: 0        ISBN-13 Fiction/Non-fiction  \
# 0                0  9780195153446          Nonfiction
# 1                1  9780002005012             Fiction
# 2                2  9780060973124          Nonfiction
# 3                3  9780374157067          Nonfiction
# 4                4  9780393045215          Nonfiction
# ...            ...            ...                 ...
# 258327      261610  9780440400981             Fiction
# 258328      261611  9780525447641                 NaN
# 258329      261612  9780060086671          Nonfiction
# 258330      261613  9780192126047          Nonfiction
# 258331      261614  9780767409759                 NaN
#
#                                                Categories  \
# 0       Mythology & Religion & Spirituality, History, ...
# 1                                     History, Literature
# 2                                                 History
# 3       History, Science & Math & Mathematics, Medical...
# ...

# %%
# Drop rows where the ISBN-13 number is 'ISBN-13'
df_cleaned_updated.drop(df_cleaned_updated[df_cleaned_updated['ISBN-13'] == 'ISBN-13'].index, inplace=True)

# %%
row = df_cleaned_updated[df_cleaned_updated['ISBN-13'] == '9780440507161']
row
# Out:
#        Unnamed: 0        ISBN-13 Fiction/Non-fiction  \
# 40436       40794  9780440507161          Nonfiction
#
#                                               Categories  \
# 40436  Science Fiction & Fantasy, Reference & Languag...
#
#          First Three Categories                          Remaining Categories
# 40436  Star Trek, Reference, Tv  Humor, Star Trek The Next Generation, Trivia

# %%
df_cleaned_updated
# Out:
#         Unnamed: 0        ISBN-13 Fiction/Non-fiction  \
# 0                0  9780195153446          Nonfiction
# 1                1  9780002005012             Fiction
# 2                2  9780060973124          Nonfiction
# 3                3  9780374157067          Nonfiction
# 4                4  9780393045215          Nonfiction
# ...            ...            ...                 ...
# 258327      261610  9780440400981             Fiction
# 258328      261611  9780525447641                 NaN
# 258329      261612  9780060086671          Nonfiction
# 258330      261613  9780192126047          Nonfiction
# 258331      261614  9780767409759                 NaN
#
#                                                Categories  \
# 0       Mythology & Religion & Spirituality, History, ...
# 1                                     History, Literature
# 2                                                 History
# 3       History, Science & Math & Mathematics, Medical...
# ...

# %%
df_sci_fic = pd.read_csv('/content/drive/MyDrive/output_updated_latest_cleaned - Science Fiction & Fantasy + Nonfiction.csv')

# %%
df_sci_fic
# Out:
#            ISBN-13 Fiction/Non-fiction  \
# 0    9780785815143          Nonfiction
# 1    9780765341976          Nonfiction
# 2    9780590514774          Nonfiction
# 3    9780553255959          Nonfiction
# 4    9780007103997          Nonfiction
# ..             ...                 ...
# 795  9780060168643          Nonfiction
# 796  9780517162286          Nonfiction
# 797  9780806999159          Nonfiction
# 798  9781892523112          Nonfiction
# 799  9783548740140          Nonfiction
#
#                                             Categories  \
# 0                  Mythology & Religion & Spirituality
# 1      Mystery & Thriller & Suspense & Horror, History
# 2                 Science Fiction & Fantasy, Meta Text
# 3    Astrology, Science Fiction & Fantasy, Science ...
# 4    Science Fiction & Fantasy, Mythology & Religio...
# ..                                                 ...
# 795  Science & Math & Mathematics, History, Science...
# ...

# %%
scific_isbn = df_sci_fic['ISBN-13'].tolist()
len(scific_isbn)
# Out:
# 800

# %%
isbn_13_string = df_cleaned_updated['ISBN-13'].tolist()
isbn_13_string
# Out:
# ['9780195153446',
#  '9780002005012',
#  '9780060973124',
#  '9780374157067',
#  '9780393045215',
#  '9780399135781',
#  '9780425176429',
#  '9780671870430',
#  '9780679425601',
#  '9780743226783',
#  '9780771074677',
#  '9780806521213',
#  '9781552041772',
#  '9781558746213',
#  '9781567407785',
#  '9781575663937',
#  '9781881320180',
#  '9780440234746',
#  '9780452264465',
#  '9780609804612',
#  '9781841721521',
#  '9781879384491',
#  '9780061076039',
#  '9780439095020',
#  '9780689821165',
#  '9780971880108',
#  '9780345402875',
#  '9780345417626',
#  '9780684823805',
#  '9780375759772',
#  '9780425163092',
#  '9783404921034',
#  '9783442353866',
#  '9783442410668',
#  '9783442446933',
#  '9780375406324',
#  '9780446310789',
#  '9780449005613',
#  '9780060168018',
#  '9780380782437',
#  '9780553212150',
#  '9780671765378',
#  '9780061099687',
#  '9780553582901',
#  '9780671888589',
#  '9780553582741',
#  '9780425182901',
#  '9780425186305',
#  '9780440223573',
#  '9780812523874',
# ...

# %%
# Convert only numeric strings to integers, skip 'ISBN-13'
isbn_13 = [int(num_str) if num_str != 'ISBN-13' else num_str for num_str in isbn_13_string]

# %%
len(isbn_13)
# Out:
# 258332

# %%
all_cat = df_cleaned_updated['Categories'].tolist()
all_cat
# Out:
# ['Mythology & Religion & Spirituality, History, Literature, Reference & Language',
#  'History, Literature',
#  'History',
#  'History, Science & Math & Mathematics, Medical, Health & Fitness & Dieting',
#  'History, Humanities',
#  'History, Literature',
#  'History',
#  'Mystery & Thriller & Suspense & Horror',
#  'History, Mystery & Thriller & Suspense & Horror',
#  'Literature, Science & Math & Mathematics',
#  'Literature',
#  'History',
#  nan,
#  'Self-Help & Motivation, Mythology & Religion & Spirituality, Biographies & Memoir',
#  nan,
#  'History',
#  nan,
#  'Mystery & Thriller & Suspense & Horror',
#  'Literature, History, Arts & Photography',
#  'Humor & Entertainment, History, Humanities, Reference & Language',
#  'Cookbooks & Food & Wine, Reference & Language, Health & Fitness & Dieting',
#  nan,
#  'Teen & Young Adult, Childrens Book',
#  'Childrens Book',
#  'History, Teen & Young Adult, Childrens Book, Mystery & Thriller & Suspense & Horror',
# ...

# %%
fic_nonfic = df_cleaned_updated['Fiction/Non-fiction'].tolist()
fic_nonfic
# Out:
# ['Nonfiction',
#  'Fiction',
#  'Nonfiction',
#  'Nonfiction',
#  'Nonfiction',
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Fiction',
#  'Nonfiction',
#  nan,
#  'Nonfiction',
#  nan,
#  'Nonfiction',
#  nan,
#  'Fiction',
#  'Fiction',
#  'Nonfiction',
#  nan,
#  nan,
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  nan,
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  nan,
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  nan,
#  'Nonfiction',
#  'Fiction',
#  nan,
#  'Fiction',
#  'Nonfiction',
#  nan,
#  nan,
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  nan,
#  'Nonfiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  nan,
#  'Nonfiction',
#  'Fiction',
#  'Fiction',
#  nan,
# ...

# %%
isbn_13
fic_nonfic
all_cat
# Out:
# ['Mythology & Religion & Spirituality, History, Literature, Reference & Language',
#  'History, Literature',
#  'History',
#  'History, Science & Math & Mathematics, Medical, Health & Fitness & Dieting',
#  'History, Humanities',
#  'History, Literature',
#  'History',
#  'Mystery & Thriller & Suspense & Horror',
#  'History, Mystery & Thriller & Suspense & Horror',
#  'Literature, Science & Math & Mathematics',
#  'Literature',
#  'History',
#  nan,
#  'Self-Help & Motivation, Mythology & Religion & Spirituality, Biographies & Memoir',
#  nan,
#  'History',
#  nan,
#  'Mystery & Thriller & Suspense & Horror',
#  'Literature, History, Arts & Photography',
#  'Humor & Entertainment, History, Humanities, Reference & Language',
#  'Cookbooks & Food & Wine, Reference & Language, Health & Fitness & Dieting',
#  nan,
#  'Teen & Young Adult, Childrens Book',
#  'Childrens Book',
#  'History, Teen & Young Adult, Childrens Book, Mystery & Thriller & Suspense & Horror',
# ...

# %%
len(scific_isbn)
# Out:
# 800

# %%
len(isbn_13)
# Out:
# 258332

# %%
len(df_cleaned_updated)
# Out:
# 258332

# %%
import pandas as pd
import math

# Assuming your dataframe is named df_cleaned_updated
# Assuming scific_isbn and isbn_13 are lists of ISBN numbers
count_val = 0

# Iterate over each pair of ISBN numbers
for idx, val in enumerate(scific_isbn):
    for index, val2 in enumerate(isbn_13):
      if val2 == 'ISBN-13':
        continue
      else:
        if val == val2:
            count_val += 1
            # Remove "Science Fiction & Fantasy" from the Categories column
            categories = df_cleaned_updated.at[index, 'Categories']
            if isinstance(categories, str):

                categories = [cat.strip() for cat in categories.split(',')]
                print('ISBN no:', val2, ' and categories :', categories)
                if 'Science Fiction & Fantasy' in categories:
                    print('Category before removal:', categories, ' and ISBN no: ', val2)
                    categories.remove('Science Fiction & Fantasy')
                    df_cleaned_updated.at[index, 'Categories'] = ', '.join(categories)
                    print('Category after removal:', categories)
            elif isinstance(categories, float):
                # Handle NaN values in the Categories column
                # You can choose to do nothing or handle it as per your requirement
                pass

# Save the modified dataframe to a file
df_cleaned_updated.to_csv('/content/drive/MyDrive/output_data_final_refine.csv', index=False)
# Out:
# ISBN no: 9780785815143  and categories : ['Mythology & Religion & Spirituality', 'Science Fiction & Fantasy']
# Category before removal: ['Mythology & Religion & Spirituality', 'Science Fiction & Fantasy']  and ISBN no:  9780785815143
# Category after removal: ['Mythology & Religion & Spirituality']
# ISBN no: 9780765341976  and categories : ['Mystery & Thriller & Suspense & Horror', 'History', 'Science Fiction & Fantasy']
# Category before removal: ['Mystery & Thriller & Suspense & Horror', 'History', 'Science Fiction & Fantasy']  and ISBN no:  9780765341976
# Category after removal: ['Mystery & Thriller & Suspense & Horror', 'History']
# ISBN no: 9780590514774  and categories : ['Science Fiction & Fantasy']
# Category before removal: ['Science Fiction & Fantasy']  and ISBN no:  9780590514774
# Category after removal: []
# ...

# %%
df_cleaned_updated.to_csv('/content/drive/MyDrive/output_data_refined_final_two.csv', index=False)

# %%
if 9780399504426 in scific_isbn:
  print('yes')
# Out:
# yes

# %%
import pandas as pd

# Assuming your dataframe is named df_cleaned_updated
# Assuming scific_isbn and isbn_13 are lists of ISBN numbers

# Iterate over each pair of ISBN numbers
for idx, val in enumerate(scific_isbn):
    for index, val2 in enumerate(isbn_13):
        if val == val2:
            # Remove "Science Fiction & Fantasy" from the Categories column
            categories = df_cleaned_updated.at[index, 'Categories']
            if isinstance(categories, str):
                # Convert categories to lowercase and strip whitespaces
                categories = [cat.strip().lower() for cat in categories.split(',')]
                # Convert 'Science Fiction & Fantasy' to lowercase
                sci_fic_fantasy = 'science fiction & fantasy'.lower()
                if sci_fic_fantasy in categories:
                    print('Category before removal:', categories)
                    categories.remove(sci_fic_fantasy)
                    df_cleaned_updated.at[index, 'Categories'] = ', '.join(categories)
                    print('Category after removal:', categories)
            elif pd.isna(categories):
                # Handle NaN values in the Categories column
                # You can choose to do nothing or handle it as per your requirement
                pass

# Save the modified dataframe to a file
df_cleaned_updated.to_csv('/content/drive/MyDrive/output_refined_data.csv', index=False)

# %% [markdown]
# Script for separating the data

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
csv_path = pd.read_csv('/content/drive/MyDrive/4.1.selected_data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = csv_path
df.head()
# Out:
#             ISBN Fiction/Non-fiction  \
# 0  9780439095020          Nonfiction
# 1  9780446310789             Fiction
# 2  9780060168018             Fiction
# 3  9780671888589             Fiction
# 4  9780553062045             Fiction
#
#                                         Categories  \
# 0                                   Childrens Book
# 1          Literature, History, Teen & Young Adult
# 2                  Literature, Fashion & Lifestyle
# 3           Mystery & Thriller & Suspense & Horror
# 4  History, Mystery & Thriller & Suspense & Horror
#
#                           First Three Categories     Coverpage   Description
# 0                                      Childrens   2587531.jpg   2587531.txt
# 1           Classics, Historical Fiction, School  25587975.jpg  25587975.txt
# 2  Contemporary, Literary Fiction, Adult Fiction    830664.jpg    830664.txt
# 3                    Mystery, Suspense, Thriller     43352.jpg     43352.txt
# ...

# %%
len(df)
# Out:
# 46016

# %%
fic_nonfic = df['Fiction/Non-fiction'].tolist()
fic_nonfic
# Out:
# ['Nonfiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Nonfiction',
#  'Nonfiction',
#  'Fiction',
#  'Nonfiction',
#  'Nonfiction',
#  'Nonfiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Nonfiction',
#  'Fiction',
#  'Nonfiction',
# ...

# %%
categories = df['Categories'].tolist()
categories
# Out:
# ['Childrens Book',
#  'Literature, History, Teen & Young Adult',
#  'Literature, Fashion & Lifestyle',
#  'Mystery & Thriller & Suspense & Horror',
#  'History, Mystery & Thriller & Suspense & Horror',
#  'Literature, Teen & Young Adult',
#  'Science Fiction & Fantasy, Literature, Mystery & Thriller & Suspense & Horror',
#  'History, Romance, Literature',
#  'Teen & Young Adult, Literature, Childrens Book',
#  'Mystery & Thriller & Suspense & Horror',
#  'Mystery & Thriller & Suspense & Horror, Travel, Literature',
#  'Mystery & Thriller & Suspense & Horror',
#  'Literature, Romance, History',
#  'Literature, Science Fiction & Fantasy, Teen & Young Adult',
#  'History, Literature',
#  'Mystery & Thriller & Suspense & Horror',
#  'Mystery & Thriller & Suspense & Horror, Science Fiction & Fantasy',
#  'Mystery & Thriller & Suspense & Horror',
#  'Science Fiction & Fantasy, Fashion & Lifestyle, Literature',
# ...

# %%
genres_numbers_fic = 0
genres_numbers_nonfic = 0
gen = "Teen & Young Adult"
for idx, gen_list in enumerate(categories):
  if pd.notna(gen_list):
    if gen in gen_list and fic_nonfic[idx] == 'Fiction':
      genres_numbers_fic += 1
    elif gen in gen_list and fic_nonfic[idx] == 'Nonfiction':
      genres_numbers_nonfic += 1
print(genres_numbers_fic)
print(genres_numbers_nonfic)
# cleaned_genres
# Out:
# 6416
# 363

# %%
count = 0
to_search = 'Crafts & Hobbies & Home'
new_dataframe = pd.DataFrame()  # Initialize a new DataFrame to store the selected rows
for idx, val in enumerate(categories):
  if pd.notna(val):
    if to_search in val and fic_nonfic[idx] == 'Fiction':
      count += 1
      new_dataframe = new_dataframe.append(df.iloc[idx])

count
# Out:
# <ipython-input-145-73d86d9baca2>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(df.iloc[idx])
# <ipython-input-145-73d86d9baca2>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(df.iloc[idx])
# <ipython-input-145-73d86d9baca2>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(df.iloc[idx])
# <ipython-input-145-73d86d9baca2>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(df.iloc[idx])
# ...

# %%
new_dataframe
# Out:
#                 ISBN Fiction/Non-fiction  \
# 15170  9780425193891             Fiction
# 16072  9780425175118             Fiction
# 17348  9780425167809             Fiction
# 18048  9780425190746             Fiction
# 21714  9780425194348             Fiction
# 23159  9780452284678             Fiction
# 25952  9780743236133             Fiction
# 32175  9780425198278             Fiction
# 32354  9780743236157             Fiction
# 40671  9780451628725             Fiction
# 41014  9780743260183             Fiction
# 45446  9780823413287             Fiction
#
#                                               Categories  \
# 15170  Mystery & Thriller & Suspense & Horror, Fashio...
# 16072  Mystery & Thriller & Suspense & Horror, Fashio...
# 17348  Mystery & Thriller & Suspense & Horror, Crafts...
# 18048  Mystery & Thriller & Suspense & Horror, Crafts...
# 21714  Mystery & Thriller & Suspense & Horror, Litera...
# 23159  History, Literature, Mystery & Thriller & Susp...
# ...

# %%
new_dataframe.to_csv('/content/drive/MyDrive/Crafts&Hobbies&Home_and_Fic.csv', index = False)
